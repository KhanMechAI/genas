# %%
import numpy as np
from queue import Queue
from collections import defaultdict
import networkx as nx
from networkx import DiGraph

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

import torchvision
from torchvision import datasets, transforms

from genotype.genotype import RandomArchitectureGenerator

# %%
# %load_ext autoreload
# %autoreload 2

# %%
rag = RandomArchitectureGenerator(min_depth=10, max_depth=75)

# %%
g, a = rag.get_architecture(reset_on_finish=False)
# Out:
# Final depth:2
# Number of nodes:4

# %%
rag.show(g, a, labels='type')

# %%
def get_torch_layer(node_attributes, graph, node_number):
    if node_attributes['TYPE'] == 'CONV':

# %%
layers = dict()
for k, v in a.items():
    torch_layer = get_torch_layer(v)
    layers[k] = torch_layer

# %%
[x for x in g.predecessors(23) if a[x]['TYPE'] in POOL_TYPES]
# Out:
# [20]

# %%
POOL_TYPES = {'MAX', 'AVERAGE'}

# %%
RandomArchitectureGenerator.__code__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-198-d334d347885d> in <module>
# ----> 1 RandomArchitectureGenerator.__code__
#
# AttributeError: type object 'RandomArchitectureGenerator' has no attribute '__code__'

# %%
dir(genotype.genotype)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-199-c9cb3fbf3bb9> in <module>
# ----> 1 dir(genotype.genotype)
#
# NameError: name 'genotype' is not defined

# %%
import genotype.genotype as gene

# %%
dir(gene)
# Out:
# ['DiGraph',
#  'Queue',
#  'RandomArchitectureGenerator',
#  'Tuple',
#  'Union',
#  '__builtins__',
#  '__cached__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'defaultdict',
#  'np',
#  'nx',
#  'plt']

# %%
dir(gene.RandomArchitectureGenerator)
# Out:
# ['BINARY_TYPES',
#  'DEFAULT_IMAGE_SIZE',
#  'FEATURE_MAPS',
#  'MAX_DEPTH',
#  'MAX_ITER',
#  'MIN_DEPTH',
#  'NODE_TYPES',
#  'POOL_TYPES',
#  'TYPE_MAP',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_increment_counters',
#  '_pool_predecessors',
#  '_type_map',
#  'add_missing_edges',
#  'add_new_node',
#  'connected_to_input',
#  'disallowed_types',
#  'get_architecture',
#  'pool_count',
#  'prune_pool_nodes',
#  'random_new_node',
#  'random_node_from_graph',
#  'reset',
#  'show']
